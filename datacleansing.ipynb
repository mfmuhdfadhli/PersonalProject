# %%
pip install pandas matplotlib seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Importing required dataset from local directory and call it df
df = pd.read_csv("C:/Users/user/OneDrive/Desktop/Python Script/Soccer-Stats-Premier-League-2023-2024_Final_20240610.csv")
df.head()
# Out:
#       Id            Name  Weight(kg)  Height(cm)   Age Citizenship  \
# 0   28.0  Erling Haaland        87.0       193.0  23.0      Norway
# 1   24.0     Cole Palmer        73.0       183.0  22.0     England
# 2  464.0  Alexander Isak        77.0       193.0  24.0      Sweden
# 3  423.0   Ollie Watkins        69.0       180.0  28.0     England
# 4   20.0      Phil Foden        69.0       170.0  23.0     England
#
#                Team  Jersey    Position  Total Play Time(min)  ...  redCards  \
# 0   Manchester City     9.0     Forward                2733.0  ...       0.0
# 1           Chelsea    20.0  Midfielder                2822.0  ...       0.0
# 2  Newcastle United    14.0     Forward                2399.0  ...       0.0
# 3       Aston Villa    11.0     Forward                3483.0  ...       0.0
# 4   Manchester City    47.0  Midfielder                3039.0  ...       0.0
#
#    goalAssists  shotsOnTarget  totalShots  totalGoals  goalsConceded  \
# ...

# %%
# a quick summary of our DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 892 entries, 0 to 891
# Data columns (total 28 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Id                      746 non-null    float64
#  1   Name                    634 non-null    object
#  2   Weight(kg)              487 non-null    float64
#  3   Height(cm)              540 non-null    float64
#  4   Age                     632 non-null    float64
#  5   Citizenship             630 non-null    object
#  6   Team                    634 non-null    object
#  7   Jersey                  633 non-null    float64
#  8   Position                634 non-null    object
#  9   Total Play Time(min)    746 non-null    float64
#  10  Average Play Time(min)  746 non-null    float64
#  11  Appearances             746 non-null    float64
#  12  subIns                  746 non-null    float64
#  13  foulsCommitted          746 non-null    float64
# ...

# %%
# Show rows where the 'name' column has NaN values
rows_with_nan_name = df[df['Name'].isna()]

# Display the rows with NaN in the 'name' column
print("Rows with NaN in 'Name' column:")
print(rows_with_nan_name)
# Out:
# Rows with NaN in 'Name' column:
#         Id Name  Weight(kg)  Height(cm)  Age Citizenship Team  Jersey  \
# 192  301.0  NaN         NaN         NaN  NaN         NaN  NaN     NaN
# 193  636.0  NaN         NaN         NaN  NaN         NaN  NaN     NaN
# 226  180.0  NaN         NaN         NaN  NaN         NaN  NaN     NaN
# 268  411.0  NaN         NaN         NaN  NaN         NaN  NaN     NaN
# 270  192.0  NaN         NaN         NaN  NaN         NaN  NaN     NaN
# ..     ...  ...         ...         ...  ...         ...  ...     ...
# 887    NaN  NaN         NaN         NaN  NaN         NaN  NaN     NaN
# 888    NaN  NaN         NaN         NaN  NaN         NaN  NaN     NaN
# 889    NaN  NaN         NaN         NaN  NaN         NaN  NaN     NaN
# 890    NaN  NaN         NaN         NaN  NaN         NaN  NaN     NaN
# 891    NaN  NaN         NaN         NaN  NaN         NaN  NaN     NaN
#
#     Position  Total Play Time(min)  ...  redCards  goalAssists  shotsOnTarget  \
# ...

# %%
# Count the number of rows with NaN in the 'name' column
num_rows_with_nan_name = rows_with_nan_name.shape[0]

# Display the count of rows with NaN in the 'name' column
print(f"Total number of rows with NaN in 'name' column: {num_rows_with_nan_name}")
# Out:
# Total number of rows with NaN in 'name' column: 258

# %%
# Remove rows where the 'name' column has NaN values
df_cleaned = df.dropna(subset=['Name'])

# Display the DataFrame after removing rows with NaN in the 'name' column
print("DataFrame after removing rows with NaN in 'Name' column:")
print(df_cleaned.head())
# Out:
# DataFrame after removing rows with NaN in 'Name' column:
#       Id            Name  Weight(kg)  Height(cm)   Age Citizenship  \
# 0   28.0  Erling Haaland        87.0       193.0  23.0      Norway
# 1   24.0     Cole Palmer        73.0       183.0  22.0     England
# 2  464.0  Alexander Isak        77.0       193.0  24.0      Sweden
# 3  423.0   Ollie Watkins        69.0       180.0  28.0     England
# 4   20.0      Phil Foden        69.0       170.0  23.0     England
#
#                Team  Jersey    Position  Total Play Time(min)  ...  redCards  \
# 0   Manchester City     9.0     Forward                2733.0  ...       0.0
# 1           Chelsea    20.0  Midfielder                2822.0  ...       0.0
# 2  Newcastle United    14.0     Forward                2399.0  ...       0.0
# 3       Aston Villa    11.0     Forward                3483.0  ...       0.0
# 4   Manchester City    47.0  Midfielder                3039.0  ...       0.0
#
# ...

# %%
# Print the shape of the cleaned DataFrame
print(f"Shape of the DataFrame after removing rows with NaN in 'name' column: {df_cleaned.shape}")

# Display the first few rows of the cleaned DataFrame
print("First few rows of the cleaned DataFrame:")
print(df_cleaned.head())
# Out:
# Shape of the DataFrame after removing rows with NaN in 'name' column: (634, 28)
# First few rows of the cleaned DataFrame:
#       Id            Name  Weight(kg)  Height(cm)   Age Citizenship  \
# 0   28.0  Erling Haaland        87.0       193.0  23.0      Norway
# 1   24.0     Cole Palmer        73.0       183.0  22.0     England
# 2  464.0  Alexander Isak        77.0       193.0  24.0      Sweden
# 3  423.0   Ollie Watkins        69.0       180.0  28.0     England
# 4   20.0      Phil Foden        69.0       170.0  23.0     England
#
#                Team  Jersey    Position  Total Play Time(min)  ...  redCards  \
# 0   Manchester City     9.0     Forward                2733.0  ...       0.0
# 1           Chelsea    20.0  Midfielder                2822.0  ...       0.0
# 2  Newcastle United    14.0     Forward                2399.0  ...       0.0
# 3       Aston Villa    11.0     Forward                3483.0  ...       0.0
# ...

# %%
# Display the DataFrame after removing rows with NaN in the 'name' column
print("DataFrame after removing rows with NaN in 'name' column:")
print(df_cleaned)
# Out:
# DataFrame after removing rows with NaN in 'name' column:
#         Id                Name  Weight(kg)  Height(cm)   Age Citizenship  \
# 0     28.0      Erling Haaland        87.0       193.0  23.0      Norway
# 1     24.0         Cole Palmer        73.0       183.0  22.0     England
# 2    464.0      Alexander Isak        77.0       193.0  24.0      Sweden
# 3    423.0       Ollie Watkins        69.0       180.0  28.0     England
# 4     20.0          Phil Foden        69.0       170.0  23.0     England
# ..     ...                 ...         ...         ...   ...         ...
# 741  892.0       Billy Blacker         NaN         NaN  17.0     England
# 742  900.0  Dovydas Sasnauskas         NaN         NaN   NaN   Lithuania
# 743  898.0     Dominic Martins         NaN         NaN  18.0    Portugal
# 744  917.0  Christian Chigozie         NaN         NaN   NaN     England
# 745  926.0        Owen Hampson         NaN         NaN  19.0     England
#
# ...

# %%
# Creates a deep copy of the DataFrame df and assigns it to a new variable df_clean
df_clean = df.copy()

# Removes duplicate rows from the df_clean DataFrame based on the values in the column specified by the subset parameter, which in this case is the 'Name' column.
df_clean = df_clean.drop_duplicates(subset=['Name'])

# %%
# Total number of rows that are considered duplicates
df_clean.duplicated(subset=['Name']).sum()
# Out:
# 0

# %%
# Display the DataFrame after removing duplicates in the 'name' column
print("DataFrame after removing duplicate values in 'name' column:")
print(df_cleaned)

# Print the shape of the cleaned DataFrame
print(f"Shape of the DataFrame after removing duplicates: {df_cleaned.shape}")

# Display the remaining rows to confirm
print("Remaining rows after removing duplicates:")
print(df_cleaned)
# Out:
# DataFrame after removing duplicate values in 'name' column:
#         Id                Name  Weight(kg)  Height(cm)   Age Citizenship  \
# 0     28.0      Erling Haaland        87.0       193.0  23.0      Norway
# 1     24.0         Cole Palmer        73.0       183.0  22.0     England
# 2    464.0      Alexander Isak        77.0       193.0  24.0      Sweden
# 3    423.0       Ollie Watkins        69.0       180.0  28.0     England
# 4     20.0          Phil Foden        69.0       170.0  23.0     England
# ..     ...                 ...         ...         ...   ...         ...
# 741  892.0       Billy Blacker         NaN         NaN  17.0     England
# 742  900.0  Dovydas Sasnauskas         NaN         NaN   NaN   Lithuania
# 743  898.0     Dominic Martins         NaN         NaN  18.0    Portugal
# 744  917.0  Christian Chigozie         NaN         NaN   NaN     England
# 745  926.0        Owen Hampson         NaN         NaN  19.0     England
#
# ...

# %%
# Show Null Values
df.isna().sum().sort_values(ascending=False)
# Out:
# Unnamed: 27               892
# Weight(kg)                405
# Height(cm)                352
# Citizenship               262
# Age                       260
# Jersey                    259
# Position                  258
# Name                      258
# Update Time               258
# Team                      258
# redCards                  146
# saves                     146
# shotsFaced                146
# goalsConceded             146
# totalGoals                146
# totalShots                146
# shotsOnTarget             146
# goalAssists               146
# Id                        146
# yellowCards               146
# offsides                  146
# ownGoals                  146
# foulsCommitted            146
# subIns                    146
# Appearances               146
# Average Play Time(min)    146
# Total Play Time(min)      146
# foulsSuffered             146
# dtype: int64

# %%
# Define the path where the cleaned CSV file will be saved
cleaned_file_path = 'cleaneddata.csv'

# Save the cleaned DataFrame to a new CSV file
df_cleaned.to_csv(cleaned_file_path, index=False)

print(f"Cleaned data has been saved to {cleaned_file_path}")
# Out:
# Cleaned data has been saved to cleaneddata.csv
